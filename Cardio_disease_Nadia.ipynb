# %%
#pip install matplotlib seaborn
#!pip install scikit-learn

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
file_name = "Disease_Data.csv"

# %%
df = pd.read_csv(file_name, sep = ';')

pd.set_option('display.max_columns', None)
df.head(20)
# Out:
# /var/folders/k7/rck94jsj7w3_47f2r29h3vn80000gn/T/ipykernel_2372/3129217793.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, sep = ';')
#                                        RowId  YearStart LocationAbbr  \
# 0   NVSS~2000~1~NV001~OVR01~Age-Standardized       2000           AL
# 1              NVSS~2000~1~NV001~OVR01~Crude       2000           AL
# 2              NVSS~2000~1~NV001~GEN01~Crude       2000           AL
# 3   NVSS~2000~1~NV001~GEN01~Age-Standardized       2000           AL
# 4   NVSS~2000~1~NV001~GEN02~Age-Standardized       2000           AL
# 5              NVSS~2000~1~NV001~GEN02~Crude       2000           AL
# 6              NVSS~2000~1~NV001~AGE01~Crude       2000           AL
# 7              NVSS~2000~1~NV001~AGE04~Crude       2000           AL
# 8              NVSS~2000~1~NV001~AGE05~Crude       2000           AL
# 9              NVSS~2000~1~NV001~AGE06~Crude       2000           AL
# 10             NVSS~2000~1~NV001~AGE07~Crude       2000           AL
# 11             NVSS~2000~1~NV001~AGE08~Crude       2000           AL
# 12             NVSS~2000~1~NV001~RAC01~Crude       2000           AL
# 13  NVSS~2000~1~NV001~RAC01~Age-Standardized       2000           AL
# 14  NVSS~2000~1~NV001~RAC02~Age-Standardized       2000           AL
# 15             NVSS~2000~1~NV001~RAC02~Crude       2000           AL
# 16  NVSS~2000~1~NV001~RAC04~Age-Standardized       2000           AL
# 17             NVSS~2000~1~NV001~RAC04~Crude       2000           AL
# 18             NVSS~2000~1~NV001~RAC07~Crude       2000           AL
# 19  NVSS~2000~1~NV001~RAC07~Age-Standardized       2000           AL
#
#    LocationDesc DataSource PriorityArea1  PriorityArea2 PriorityArea3  \
# 0       Alabama       NVSS           NaN            NaN           NaN
# 1       Alabama       NVSS           NaN            NaN           NaN
# 2       Alabama       NVSS           NaN            NaN           NaN
# 3       Alabama       NVSS           NaN            NaN           NaN
# 4       Alabama       NVSS           NaN            NaN           NaN
# 5       Alabama       NVSS           NaN            NaN           NaN
# 6       Alabama       NVSS           NaN            NaN           NaN
# 7       Alabama       NVSS           NaN            NaN           NaN
# 8       Alabama       NVSS           NaN            NaN           NaN
# 9       Alabama       NVSS           NaN            NaN           NaN
# 10      Alabama       NVSS           NaN            NaN           NaN
# 11      Alabama       NVSS           NaN            NaN           NaN
# 12      Alabama       NVSS           NaN            NaN           NaN
# 13      Alabama       NVSS           NaN            NaN           NaN
# 14      Alabama       NVSS           NaN            NaN           NaN
# 15      Alabama       NVSS           NaN            NaN           NaN
# 16      Alabama       NVSS           NaN            NaN           NaN
# 17      Alabama       NVSS           NaN            NaN           NaN
# 18      Alabama       NVSS           NaN            NaN           NaN
# 19      Alabama       NVSS           NaN            NaN           NaN
#
#     PriorityArea4                    Class                         Topic  \
# 0             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 1             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 2             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 3             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 4             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 5             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 6             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 7             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 8             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 9             NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 10            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 11            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 12            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 13            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 14            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 15            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 16            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 17            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 18            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 19            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
#
#                                              Question   Data_Value_Type  \
# 0   Major cardiovascular disease mortality rate am...  Age-Standardized
# 1   Major cardiovascular disease mortality rate am...             Crude
# 2   Major cardiovascular disease mortality rate am...             Crude
# 3   Major cardiovascular disease mortality rate am...  Age-Standardized
# 4   Major cardiovascular disease mortality rate am...  Age-Standardized
# 5   Major cardiovascular disease mortality rate am...             Crude
# 6   Major cardiovascular disease mortality rate am...             Crude
# 7   Major cardiovascular disease mortality rate am...             Crude
# 8   Major cardiovascular disease mortality rate am...             Crude
# 9   Major cardiovascular disease mortality rate am...             Crude
# 10  Major cardiovascular disease mortality rate am...             Crude
# 11  Major cardiovascular disease mortality rate am...             Crude
# 12  Major cardiovascular disease mortality rate am...             Crude
# 13  Major cardiovascular disease mortality rate am...  Age-Standardized
# 14  Major cardiovascular disease mortality rate am...  Age-Standardized
# 15  Major cardiovascular disease mortality rate am...             Crude
# 16  Major cardiovascular disease mortality rate am...  Age-Standardized
# 17  Major cardiovascular disease mortality rate am...             Crude
# 18  Major cardiovascular disease mortality rate am...             Crude
# 19  Major cardiovascular disease mortality rate am...  Age-Standardized
#
#      Data_Value_Unit Data_Value Data_Value_Alt Data_Value_Footnote_Symbol  \
# 0   Rate per 100,000      508,2          508,2                        NaN
# 1   Rate per 100,000      525,6          525,6                        NaN
# 2   Rate per 100,000      514,9          514,9                        NaN
# 3   Rate per 100,000      550,4          550,4                        NaN
# 4   Rate per 100,000      471,7          471,7                        NaN
# 5   Rate per 100,000      535,3          535,3                        NaN
# 6   Rate per 100,000        5,4            5,4                        NaN
# 7   Rate per 100,000       38,2           38,2                        NaN
# 8   Rate per 100,000      273,4          273,4                        NaN
# 9   Rate per 100,000    2.442,8        2.442,8                        NaN
# 10  Rate per 100,000      759,7          759,7                        NaN
# 11  Rate per 100,000    4.106,7        4.106,7                        NaN
# 12  Rate per 100,000      549,6          549,6                        NaN
# 13  Rate per 100,000      489,8          489,8                        NaN
# 14  Rate per 100,000      602,8          602,8                        NaN
# 15  Rate per 100,000      508,9          508,9                        NaN
# 16  Rate per 100,000       91,9           91,9                        NaN
# 17  Rate per 100,000       42,8           42,8                        NaN
# 18  Rate per 100,000       62,4           62,4                        NaN
# 19  Rate per 100,000      118,4          118,4                        NaN
#
#    Data_Value_Footnote Low_Confidence_Limit High_Confidence_Limit  \
# 0                  NaN                508,2                 508,2
# 1                  NaN                525,6                 525,6
# 2                  NaN                514,9                 514,9
# 3                  NaN                550,4                 550,4
# 4                  NaN                471,7                 471,7
# 5                  NaN                535,3                 535,3
# 6                  NaN                  5,3                     8
# 7                  NaN                 38,1                  38,3
# 8                  NaN                273,4                 273,4
# 9                  NaN              2.442,8               2.442,8
# 10                 NaN                759,7                 759,7
# 11                 NaN              4.106,7               4.106,7
# 12                 NaN                549,6                 549,6
# 13                 NaN                489,8                 489,8
# 14                 NaN                602,8                 602,8
# 15                 NaN                508,9                 508,9
# 16                 NaN                 89,3                 139,1
# 17                 NaN                 41,6                  64,8
# 18                 NaN                 60,9                  90,8
# 19                 NaN                115,5                 172,3
#
#    Break_Out_Category           Break_Out ClassId TopicId QuestionId  \
# 0             Overall             Overall      C1      T1      NV001
# 1             Overall             Overall      C1      T1      NV001
# 2              Gender                Male      C1      T1      NV001
# 3              Gender                Male      C1      T1      NV001
# 4              Gender              Female      C1      T1      NV001
# 5              Gender              Female      C1      T1      NV001
# 6                 Age               18-24      C1      T1      NV001
# 7                 Age               25-44      C1      T1      NV001
# 8                 Age               45-64      C1      T1      NV001
# 9                 Age                  65      C1      T1      NV001
# 10                Age                  35      C1      T1      NV001
# 11                Age                  75      C1      T1      NV001
# 12               Race  Non-Hispanic White      C1      T1      NV001
# 13               Race  Non-Hispanic White      C1      T1      NV001
# 14               Race  Non-Hispanic Black      C1      T1      NV001
# 15               Race  Non-Hispanic Black      C1      T1      NV001
# 16               Race            Hispanic      C1      T1      NV001
# 17               Race            Hispanic      C1      T1      NV001
# 18               Race               Other      C1      T1      NV001
# 19               Race               Other      C1      T1      NV001
#
#    Data_Value_TypeID BreakOutCategoryId BreakOutId  LocationId  \
# 0            AgeStdz              BOC01      OVR01           1
# 1              Crude              BOC01      OVR01           1
# 2              Crude              BOC02      GEN01           1
# 3            AgeStdz              BOC02      GEN01           1
# 4            AgeStdz              BOC02      GEN02           1
# 5              Crude              BOC02      GEN02           1
# 6              Crude              BOC03      AGE01           1
# 7              Crude              BOC03      AGE04           1
# 8              Crude              BOC03      AGE05           1
# 9              Crude              BOC03      AGE06           1
# 10             Crude              BOC03      AGE07           1
# 11             Crude              BOC03      AGE08           1
# 12             Crude              BOC04      RAC01           1
# 13           AgeStdz              BOC04      RAC01           1
# 14           AgeStdz              BOC04      RAC02           1
# 15             Crude              BOC04      RAC02           1
# 16           AgeStdz              BOC04      RAC04           1
# 17             Crude              BOC04      RAC04           1
# 18             Crude              BOC04      RAC07           1
# 19           AgeStdz              BOC04      RAC07           1
#
#                          Geolocation
# 0   POINT (-86.63186076 32.84057112)
# 1   POINT (-86.63186076 32.84057112)
# 2   POINT (-86.63186076 32.84057112)
# 3   POINT (-86.63186076 32.84057112)
# 4   POINT (-86.63186076 32.84057112)
# 5   POINT (-86.63186076 32.84057112)
# 6   POINT (-86.63186076 32.84057112)
# 7   POINT (-86.63186076 32.84057112)
# 8   POINT (-86.63186076 32.84057112)
# 9   POINT (-86.63186076 32.84057112)
# 10  POINT (-86.63186076 32.84057112)
# 11  POINT (-86.63186076 32.84057112)
# 12  POINT (-86.63186076 32.84057112)
# 13  POINT (-86.63186076 32.84057112)
# 14  POINT (-86.63186076 32.84057112)
# 15  POINT (-86.63186076 32.84057112)
# 16  POINT (-86.63186076 32.84057112)
# 17  POINT (-86.63186076 32.84057112)
# 18  POINT (-86.63186076 32.84057112)
# 19  POINT (-86.63186076 32.84057112)

# %%
df.Data_Value_Unit.unique()
# Out:
# array(['Rate per 100,000'], dtype=object)

# %%
df.Break_Out.unique()
# Out:
# array(['Overall', 'Male', 'Female', '18-24', '25-44', '45-64', '65', '35',
#        '75', 'Non-Hispanic White', 'Non-Hispanic Black', 'Hispanic',
#        'Other'], dtype=object)

# %%
df.BreakOutId.unique()
# Out:
# array(['OVR01', 'GEN01', 'GEN02', 'AGE01', 'AGE04', 'AGE05', 'AGE06',
#        'AGE07', 'AGE08', 'RAC01', 'RAC02', 'RAC04', 'RAC07'], dtype=object)

# %%
df.Break_Out_Category.value_counts()
# Out:
# Break_Out_Category
# Race       69888
# Age        52416
# Gender     34944
# Overall    17472
# Name: count, dtype: int64

# %%
df.YearStart.value_counts()
# Out:
# YearStart
# 2000    8320
# 2001    8320
# 2002    8320
# 2003    8320
# 2004    8320
# 2005    8320
# 2006    8320
# 2007    8320
# 2008    8320
# 2009    8320
# 2010    8320
# 2011    8320
# 2012    8320
# 2013    8320
# 2014    8320
# 2015    8320
# 2016    8320
# 2017    8320
# 2018    8320
# 2019    8320
# 2020    8320
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# RowId                              0
# YearStart                          0
# LocationAbbr                       0
# LocationDesc                       0
# DataSource                         0
# PriorityArea1                 131040
# PriorityArea2                 174720
# PriorityArea3                 131040
# PriorityArea4                 174720
# Class                              0
# Topic                              0
# Question                           0
# Data_Value_Type                    0
# Data_Value_Unit                    0
# Data_Value                     31630
# Data_Value_Alt                     0
# Data_Value_Footnote_Symbol    143090
# Data_Value_Footnote           143090
# Low_Confidence_Limit           31630
# High_Confidence_Limit          31630
# Break_Out_Category                 0
# Break_Out                          0
# ClassId                            0
# TopicId                            0
# QuestionId                         0
# Data_Value_TypeID                  0
# BreakOutCategoryId                 0
# BreakOutId                         0
# LocationId                         0
# Geolocation                     3360
# dtype: int64

# %%
df.dtypes
# Out:
# RowId                          object
# YearStart                       int64
# LocationAbbr                   object
# LocationDesc                   object
# DataSource                     object
# PriorityArea1                  object
# PriorityArea2                 float64
# PriorityArea3                  object
# PriorityArea4                 float64
# Class                          object
# Topic                          object
# Question                       object
# Data_Value_Type                object
# Data_Value_Unit                object
# Data_Value                     object
# Data_Value_Alt                 object
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Low_Confidence_Limit           object
# High_Confidence_Limit          object
# Break_Out_Category             object
# Break_Out                      object
# ClassId                        object
# TopicId                        object
# QuestionId                     object
# Data_Value_TypeID              object
# BreakOutCategoryId             object
# BreakOutId                     object
# LocationId                      int64
# Geolocation                    object
# dtype: object

# %%
#df = df.drop(df[df['Break_Out_Category'] == 'Race'].index) 
#df = df.drop(df[df['Break_Out_Category'] == 'Gender'].index) 
#df = df.drop(df[df['Data_Value_Type'] == 'Age-Standardized'].index)

# %%
df = df.drop(df[df['Data_Value'] == ''].index) 
df = df.drop(df[df['Data_Value_Alt'] == ''].index) 
df.dropna(subset=['Data_Value'], inplace=True)

# %%
df['Data_Value'] = df['Data_Value'].str.replace(',','')
df['Data_Value_Alt'] = df['Data_Value_Alt'].str.replace(',','')

df['Data_Value'] = df['Data_Value'].astype(float)
df['Data_Value_Alt'] = df['Data_Value_Alt'].astype(float)

# %%
df.shape
# Out:
# (143090, 30)

# %%
columns = df.columns.to_list()
columns
# Out:
# ['RowId',
#  'YearStart',
#  'LocationAbbr',
#  'LocationDesc',
#  'DataSource',
#  'PriorityArea1',
#  'PriorityArea2',
#  'PriorityArea3',
#  'PriorityArea4',
#  'Class',
#  'Topic',
#  'Question',
#  'Data_Value_Type',
#  'Data_Value_Unit',
#  'Data_Value',
#  'Data_Value_Alt',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'Break_Out_Category',
#  'Break_Out',
#  'ClassId',
#  'TopicId',
#  'QuestionId',
#  'Data_Value_TypeID',
#  'BreakOutCategoryId',
#  'BreakOutId',
#  'LocationId',
#  'Geolocation']

# %%
df.isna().sum()
# Out:
# RowId                              0
# YearStart                          0
# LocationAbbr                       0
# LocationDesc                       0
# DataSource                         0
# PriorityArea1                 107561
# PriorityArea2                 143090
# PriorityArea3                 105975
# PriorityArea4                 143090
# Class                              0
# Topic                              0
# Question                           0
# Data_Value_Type                    0
# Data_Value_Unit                    0
# Data_Value                         0
# Data_Value_Alt                     0
# Data_Value_Footnote_Symbol    143090
# Data_Value_Footnote           143090
# Low_Confidence_Limit               0
# High_Confidence_Limit              0
# Break_Out_Category                 0
# Break_Out                          0
# ClassId                            0
# TopicId                            0
# QuestionId                         0
# Data_Value_TypeID                  0
# BreakOutCategoryId                 0
# BreakOutId                         0
# LocationId                         0
# Geolocation                     3357
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                             RowId  YearStart LocationAbbr  \
# 0        NVSS~2000~1~NV001~OVR01~Age-Standardized       2000           AL
# 1                   NVSS~2000~1~NV001~OVR01~Crude       2000           AL
# 2                   NVSS~2000~1~NV001~GEN01~Crude       2000           AL
# 3        NVSS~2000~1~NV001~GEN01~Age-Standardized       2000           AL
# 4        NVSS~2000~1~NV001~GEN02~Age-Standardized       2000           AL
# ...                                           ...        ...          ...
# 174715             NVSS~2020~59~NV008~RAC02~Crude       2020           US
# 174716             NVSS~2020~59~NV008~RAC04~Crude       2020           US
# 174717  NVSS~2020~59~NV008~RAC04~Age-Standardized       2020           US
# 174718  NVSS~2020~59~NV008~RAC07~Age-Standardized       2020           US
# 174719             NVSS~2020~59~NV008~RAC07~Crude       2020           US
#
#          LocationDesc DataSource PriorityArea1  PriorityArea2 PriorityArea3  \
# 0             Alabama       NVSS           NaN            NaN           NaN
# 1             Alabama       NVSS           NaN            NaN           NaN
# 2             Alabama       NVSS           NaN            NaN           NaN
# 3             Alabama       NVSS           NaN            NaN           NaN
# 4             Alabama       NVSS           NaN            NaN           NaN
# ...               ...        ...           ...            ...           ...
# 174715  United States       NVSS           NaN            NaN           NaN
# 174716  United States       NVSS           NaN            NaN           NaN
# 174717  United States       NVSS           NaN            NaN           NaN
# 174718  United States       NVSS           NaN            NaN           NaN
# 174719  United States       NVSS           NaN            NaN           NaN
#
#         PriorityArea4                    Class                         Topic  \
# 0                 NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 1                 NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 2                 NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 3                 NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 4                 NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# ...               ...                      ...                           ...
# 174715            NaN  Cardiovascular Diseases                        Stroke
# 174716            NaN  Cardiovascular Diseases                        Stroke
# 174717            NaN  Cardiovascular Diseases                        Stroke
# 174718            NaN  Cardiovascular Diseases                        Stroke
# 174719            NaN  Cardiovascular Diseases                        Stroke
#
#                                                  Question   Data_Value_Type  \
# 0       Major cardiovascular disease mortality rate am...  Age-Standardized
# 1       Major cardiovascular disease mortality rate am...             Crude
# 2       Major cardiovascular disease mortality rate am...             Crude
# 3       Major cardiovascular disease mortality rate am...  Age-Standardized
# 4       Major cardiovascular disease mortality rate am...  Age-Standardized
# ...                                                   ...               ...
# 174715  Hemorrhagic stroke mortality rate among US adu...             Crude
# 174716  Hemorrhagic stroke mortality rate among US adu...             Crude
# 174717  Hemorrhagic stroke mortality rate among US adu...  Age-Standardized
# 174718  Hemorrhagic stroke mortality rate among US adu...  Age-Standardized
# 174719  Hemorrhagic stroke mortality rate among US adu...             Crude
#
#          Data_Value_Unit  Data_Value  Data_Value_Alt  \
# 0       Rate per 100,000      5082.0          5082.0
# 1       Rate per 100,000      5256.0          5256.0
# 2       Rate per 100,000      5149.0          5149.0
# 3       Rate per 100,000      5504.0          5504.0
# 4       Rate per 100,000      4717.0          4717.0
# ...                  ...         ...             ...
# 174715  Rate per 100,000       150.0            15.0
# 174716  Rate per 100,000        84.0            84.0
# 174717  Rate per 100,000       102.0           102.0
# 174718  Rate per 100,000       116.0           116.0
# 174719  Rate per 100,000       119.0           119.0
#
#        Data_Value_Footnote_Symbol Data_Value_Footnote Low_Confidence_Limit  \
# 0                             NaN                 NaN                508,2
# 1                             NaN                 NaN                525,6
# 2                             NaN                 NaN                514,9
# 3                             NaN                 NaN                550,4
# 4                             NaN                 NaN                471,7
# ...                           ...                 ...                  ...
# 174715                        NaN                 NaN                   15
# 174716                        NaN                 NaN                  8,4
# 174717                        NaN                 NaN                 10,2
# 174718                        NaN                 NaN                 11,6
# 174719                        NaN                 NaN                 11,9
#
#        High_Confidence_Limit Break_Out_Category           Break_Out ClassId  \
# 0                      508,2            Overall             Overall      C1
# 1                      525,6            Overall             Overall      C1
# 2                      514,9             Gender                Male      C1
# 3                      550,4             Gender                Male      C1
# 4                      471,7             Gender              Female      C1
# ...                      ...                ...                 ...     ...
# 174715                    15               Race  Non-Hispanic Black      C1
# 174716                   8,4               Race            Hispanic      C1
# 174717                  10,2               Race            Hispanic      C1
# 174718                  11,6               Race               Other      C1
# 174719                  11,9               Race               Other      C1
#
#        TopicId QuestionId Data_Value_TypeID BreakOutCategoryId BreakOutId  \
# 0           T1      NV001           AgeStdz              BOC01      OVR01
# 1           T1      NV001             Crude              BOC01      OVR01
# 2           T1      NV001             Crude              BOC02      GEN01
# 3           T1      NV001           AgeStdz              BOC02      GEN01
# 4           T1      NV001           AgeStdz              BOC02      GEN02
# ...        ...        ...               ...                ...        ...
# 174715      T6      NV008             Crude              BOC04      RAC02
# 174716      T6      NV008             Crude              BOC04      RAC04
# 174717      T6      NV008           AgeStdz              BOC04      RAC04
# 174718      T6      NV008           AgeStdz              BOC04      RAC07
# 174719      T6      NV008             Crude              BOC04      RAC07
#
#         LocationId                       Geolocation
# 0                1  POINT (-86.63186076 32.84057112)
# 1                1  POINT (-86.63186076 32.84057112)
# 2                1  POINT (-86.63186076 32.84057112)
# 3                1  POINT (-86.63186076 32.84057112)
# 4                1  POINT (-86.63186076 32.84057112)
# ...            ...                               ...
# 174715          59                               NaN
# 174716          59                               NaN
# 174717          59                               NaN
# 174718          59                               NaN
# 174719          59                               NaN
#
# [143090 rows x 30 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143090 entries, 0 to 174719
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   RowId                       143090 non-null  object
#  1   YearStart                   143090 non-null  int64
#  2   LocationAbbr                143090 non-null  object
#  3   LocationDesc                143090 non-null  object
#  4   DataSource                  143090 non-null  object
#  5   PriorityArea1               35529 non-null   object
#  6   PriorityArea2               0 non-null       float64
#  7   PriorityArea3               37115 non-null   object
#  8   PriorityArea4               0 non-null       float64
#  9   Class                       143090 non-null  object
#  10  Topic                       143090 non-null  object
#  11  Question                    143090 non-null  object
#  12  Data_Value_Type             143090 non-null  object
#  13  Data_Value_Unit             143090 non-null  object
#  14  Data_Value                  143090 non-null  float64
#  15  Data_Value_Alt              143090 non-null  float64
#  16  Data_Value_Footnote_Symbol  0 non-null       object
#  17  Data_Value_Footnote         0 non-null       object
#  18  Low_Confidence_Limit        143090 non-null  object
#  19  High_Confidence_Limit       143090 non-null  object
#  20  Break_Out_Category          143090 non-null  object
#  21  Break_Out                   143090 non-null  object
#  22  ClassId                     143090 non-null  object
#  23  TopicId                     143090 non-null  object
#  24  QuestionId                  143090 non-null  object
#  25  Data_Value_TypeID           143090 non-null  object
#  26  BreakOutCategoryId          143090 non-null  object
#  27  BreakOutId                  143090 non-null  object
#  28  LocationId                  143090 non-null  int64
#  29  Geolocation                 139733 non-null  object
# dtypes: float64(4), int64(2), object(24)
# memory usage: 33.8+ MB

# %% [markdown]
# df.columns()

# %%
#df.plot_scatter('YearStart', 'Data_Value')
#df.plot.scatter(x='YearStart', y='Data_Value')
#plt.scatter(df.col1, df.col2, s=df.col3)
#plt.xlabel('YearStart')
#plt.ylabel('Data_Value')
#plt.title('Cardiovascular Disease')
#plt.show()#

# %%
#plt.hexbin(df['YearStart'], df['Data_Value'], gridsize=30, cmap='Blues')
#plt.colorbar(label='Count')
#plt.xlabel('YearStart')
#plt.ylabel('Data_Value')
#plt.title('Cardiovascular Disease')
#plt.show()

# %%
#plt.plot(df['YearStart'], df['Data_Value'])
#plt.xlabel('YearStart')
#plt.ylabel('Data_Value')
##plt.title('Cardiovascular Disease')
#plt.show()

# %%
# Convert YearStart to a categorical type for proper grouping
#df['YearStart'] = df['YearStart'].astype('category')

# Box plot
#plt.figure(figsize=(12, 8))
#sns.boxplot(x='YearStart', y='Data_Value', data=df)
#plt.xlabel('YearStart')
#plt.ylabel('Data Value')
#plt.title('Cardiovascular Disease')
#plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
#plt.show()

# %%
#plt.hexbin(df['YearStart'], df['Data_Value'], gridsize=30, cmap='Blues')
#plt.colorbar(label='Count')
#plt.xlabel('YearStart')
#plt.ylabel('Data_Value')
#plt.title('Cardiovascular Disease')
#plt.show()

# %%
#sns.pairplot(df)
#plt.suptitle('Pair Plot of YearStart and Data_Value', y=1.02)
#plt.show()

# %%
df.columns
# Out:
# Index(['RowId', 'YearStart', 'LocationAbbr', 'LocationDesc', 'DataSource',
#        'PriorityArea1', 'PriorityArea2', 'PriorityArea3', 'PriorityArea4',
#        'Class', 'Topic', 'Question', 'Data_Value_Type', 'Data_Value_Unit',
#        'Data_Value', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol',
#        'Data_Value_Footnote', 'Low_Confidence_Limit', 'High_Confidence_Limit',
#        'Break_Out_Category', 'Break_Out', 'ClassId', 'TopicId', 'QuestionId',
#        'Data_Value_TypeID', 'BreakOutCategoryId', 'BreakOutId', 'LocationId',
#        'Geolocation'],
#       dtype='object')

# %%
df.to_csv('original_dataset_backup.csv', index=False)

# %%
columns_to_drop = ['RowId', 'LocationDesc', 'DataSource', 'PriorityArea1', 'PriorityArea2', 'PriorityArea3', 'PriorityArea4', 'Question', 
                   'Data_Value_Type', 'Data_Value_Unit', 'Data_Value_Alt', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 
                   'Low_Confidence_Limit', 'High_Confidence_Limit', 'ClassId', 'TopicId', 'QuestionId',  'BreakOutCategoryId', 'BreakOutId', 'Geolocation', 'LocationId']

# %%
df = df.drop(columns=columns_to_drop)

# %%
df.columns
# Out:
# Index(['YearStart', 'LocationAbbr', 'Class', 'Topic', 'Data_Value',
#        'Break_Out_Category', 'Break_Out', 'Data_Value_TypeID'],
#       dtype='object')

# %%
#remaining columns 'YearStart', 'LocationAbbr', 'LocationDesc', 'Class', 'Topic', 'Data_Value',  'Break_Out_Category', 'Break_Out', 'Data_Value_TypeID', 'LocationId'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 143090 entries, 0 to 174719
# Data columns (total 8 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   YearStart           143090 non-null  int64
#  1   LocationAbbr        143090 non-null  object
#  2   Class               143090 non-null  object
#  3   Topic               143090 non-null  object
#  4   Data_Value          143090 non-null  float64
#  5   Break_Out_Category  143090 non-null  object
#  6   Break_Out           143090 non-null  object
#  7   Data_Value_TypeID   143090 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 9.8+ MB

# %%
df.tail(40)
# Out:
#         YearStart LocationAbbr                    Class   Topic  Data_Value  \
# 174670       2020           WI  Cardiovascular Diseases  Stroke       189.0
# 174671       2020           WI  Cardiovascular Diseases  Stroke       807.0
# 174672       2020           WI  Cardiovascular Diseases  Stroke       142.0
# 174673       2020           WI  Cardiovascular Diseases  Stroke       101.0
# 174674       2020           WI  Cardiovascular Diseases  Stroke       169.0
# 174675       2020           WI  Cardiovascular Diseases  Stroke       144.0
# 174678       2020           WI  Cardiovascular Diseases  Stroke       188.0
# 174679       2020           WI  Cardiovascular Diseases  Stroke       145.0
# 174680       2020           WY  Cardiovascular Diseases  Stroke       142.0
# 174681       2020           WY  Cardiovascular Diseases  Stroke       110.0
# 174682       2020           WY  Cardiovascular Diseases  Stroke       119.0
# 174683       2020           WY  Cardiovascular Diseases  Stroke       149.0
# 174684       2020           WY  Cardiovascular Diseases  Stroke       136.0
# 174685       2020           WY  Cardiovascular Diseases  Stroke       102.0
# 174688       2020           WY  Cardiovascular Diseases  Stroke       142.0
# 174689       2020           WY  Cardiovascular Diseases  Stroke       405.0
# 174690       2020           WY  Cardiovascular Diseases  Stroke       197.0
# 174691       2020           WY  Cardiovascular Diseases  Stroke       826.0
# 174692       2020           WY  Cardiovascular Diseases  Stroke       149.0
# 174693       2020           WY  Cardiovascular Diseases  Stroke       110.0
# 174700       2020           US  Cardiovascular Diseases  Stroke       110.0
# 174701       2020           US  Cardiovascular Diseases  Stroke       134.0
# 174702       2020           US  Cardiovascular Diseases  Stroke       133.0
# 174703       2020           US  Cardiovascular Diseases  Stroke       116.0
# 174704       2020           US  Cardiovascular Diseases  Stroke       105.0
# 174705       2020           US  Cardiovascular Diseases  Stroke       135.0
# 174706       2020           US  Cardiovascular Diseases  Stroke         3.0
# 174707       2020           US  Cardiovascular Diseases  Stroke        19.0
# 174708       2020           US  Cardiovascular Diseases  Stroke        99.0
# 174709       2020           US  Cardiovascular Diseases  Stroke       439.0
# 174710       2020           US  Cardiovascular Diseases  Stroke       188.0
# 174711       2020           US  Cardiovascular Diseases  Stroke       752.0
# 174712       2020           US  Cardiovascular Diseases  Stroke       145.0
# 174713       2020           US  Cardiovascular Diseases  Stroke       103.0
# 174714       2020           US  Cardiovascular Diseases  Stroke       149.0
# 174715       2020           US  Cardiovascular Diseases  Stroke       150.0
# 174716       2020           US  Cardiovascular Diseases  Stroke        84.0
# 174717       2020           US  Cardiovascular Diseases  Stroke       102.0
# 174718       2020           US  Cardiovascular Diseases  Stroke       116.0
# 174719       2020           US  Cardiovascular Diseases  Stroke       119.0
#
#        Break_Out_Category           Break_Out Data_Value_TypeID
# 174670                Age                  35             Crude
# 174671                Age                  75             Crude
# 174672               Race  Non-Hispanic White             Crude
# 174673               Race  Non-Hispanic White           AgeStdz
# 174674               Race  Non-Hispanic Black           AgeStdz
# 174675               Race  Non-Hispanic Black             Crude
# 174678               Race               Other           AgeStdz
# 174679               Race               Other             Crude
# 174680            Overall             Overall             Crude
# 174681            Overall             Overall           AgeStdz
# 174682             Gender                Male           AgeStdz
# 174683             Gender                Male             Crude
# 174684             Gender              Female             Crude
# 174685             Gender              Female           AgeStdz
# 174688                Age               45-64             Crude
# 174689                Age                  65             Crude
# 174690                Age                  35             Crude
# 174691                Age                  75             Crude
# 174692               Race  Non-Hispanic White             Crude
# 174693               Race  Non-Hispanic White           AgeStdz
# 174700            Overall             Overall           AgeStdz
# 174701            Overall             Overall             Crude
# 174702             Gender                Male             Crude
# 174703             Gender                Male           AgeStdz
# 174704             Gender              Female           AgeStdz
# 174705             Gender              Female             Crude
# 174706                Age               18-24             Crude
# 174707                Age               25-44             Crude
# 174708                Age               45-64             Crude
# 174709                Age                  65             Crude
# 174710                Age                  35             Crude
# 174711                Age                  75             Crude
# 174712               Race  Non-Hispanic White             Crude
# 174713               Race  Non-Hispanic White           AgeStdz
# 174714               Race  Non-Hispanic Black           AgeStdz
# 174715               Race  Non-Hispanic Black             Crude
# 174716               Race            Hispanic             Crude
# 174717               Race            Hispanic           AgeStdz
# 174718               Race               Other           AgeStdz
# 174719               Race               Other             Crude

# %%
df.dtypes
# Out:
# YearStart               int64
# LocationAbbr           object
# Class                  object
# Topic                  object
# Data_Value            float64
# Break_Out_Category     object
# Break_Out              object
# Data_Value_TypeID      object
# dtype: object

# %%
#filtered_df = df[df['YearStart'] >= 2010]
filtered_df = df[(df['Data_Value_TypeID'] == 'Crude')]

# %%
filtered_mcd_df = filtered_df[df['Topic'] == 'Major Cardiovascular Disease']
# Out:
# /var/folders/k7/rck94jsj7w3_47f2r29h3vn80000gn/T/ipykernel_2372/2225853353.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   filtered_mcd_df = filtered_df[df['Topic'] == 'Major Cardiovascular Disease']

# %%
filtered_mcd_df.head(30)
# Out:
#     YearStart LocationAbbr                    Class  \
# 1        2000           AL  Cardiovascular Diseases
# 2        2000           AL  Cardiovascular Diseases
# 5        2000           AL  Cardiovascular Diseases
# 6        2000           AL  Cardiovascular Diseases
# 7        2000           AL  Cardiovascular Diseases
# 8        2000           AL  Cardiovascular Diseases
# 9        2000           AL  Cardiovascular Diseases
# 10       2000           AL  Cardiovascular Diseases
# 11       2000           AL  Cardiovascular Diseases
# 12       2000           AL  Cardiovascular Diseases
# 15       2000           AL  Cardiovascular Diseases
# 17       2000           AL  Cardiovascular Diseases
# 18       2000           AL  Cardiovascular Diseases
# 20       2000           AK  Cardiovascular Diseases
# 23       2000           AK  Cardiovascular Diseases
# 24       2000           AK  Cardiovascular Diseases
# 27       2000           AK  Cardiovascular Diseases
# 28       2000           AK  Cardiovascular Diseases
# 29       2000           AK  Cardiovascular Diseases
# 30       2000           AK  Cardiovascular Diseases
# 31       2000           AK  Cardiovascular Diseases
# 32       2000           AK  Cardiovascular Diseases
# 35       2000           AK  Cardiovascular Diseases
# 38       2000           AK  Cardiovascular Diseases
# 41       2000           AZ  Cardiovascular Diseases
# 42       2000           AZ  Cardiovascular Diseases
# 45       2000           AZ  Cardiovascular Diseases
# 47       2000           AZ  Cardiovascular Diseases
# 48       2000           AZ  Cardiovascular Diseases
# 49       2000           AZ  Cardiovascular Diseases
#
#                            Topic  Data_Value Break_Out_Category  \
# 1   Major Cardiovascular Disease   5256.0000            Overall
# 2   Major Cardiovascular Disease   5149.0000             Gender
# 5   Major Cardiovascular Disease   5353.0000             Gender
# 6   Major Cardiovascular Disease     54.0000                Age
# 7   Major Cardiovascular Disease    382.0000                Age
# 8   Major Cardiovascular Disease   2734.0000                Age
# 9   Major Cardiovascular Disease      2.4428                Age
# 10  Major Cardiovascular Disease   7597.0000                Age
# 11  Major Cardiovascular Disease      4.1067                Age
# 12  Major Cardiovascular Disease   5496.0000               Race
# 15  Major Cardiovascular Disease   5089.0000               Race
# 17  Major Cardiovascular Disease    428.0000               Race
# 18  Major Cardiovascular Disease    624.0000               Race
# 20  Major Cardiovascular Disease   1871.0000            Overall
# 23  Major Cardiovascular Disease   1967.0000             Gender
# 24  Major Cardiovascular Disease   1767.0000             Gender
# 27  Major Cardiovascular Disease    177.0000                Age
# 28  Major Cardiovascular Disease   1410.0000                Age
# 29  Major Cardiovascular Disease      1.6121                Age
# 30  Major Cardiovascular Disease   2796.0000                Age
# 31  Major Cardiovascular Disease      3.1460                Age
# 32  Major Cardiovascular Disease   1916.0000               Race
# 35  Major Cardiovascular Disease   1893.0000               Race
# 38  Major Cardiovascular Disease   1902.0000               Race
# 41  Major Cardiovascular Disease   3724.0000            Overall
# 42  Major Cardiovascular Disease   3868.0000             Gender
# 45  Major Cardiovascular Disease   3584.0000             Gender
# 47  Major Cardiovascular Disease    206.0000                Age
# 48  Major Cardiovascular Disease   1729.0000                Age
# 49  Major Cardiovascular Disease      1.7749                Age
#
#              Break_Out Data_Value_TypeID
# 1              Overall             Crude
# 2                 Male             Crude
# 5               Female             Crude
# 6                18-24             Crude
# 7                25-44             Crude
# 8                45-64             Crude
# 9                   65             Crude
# 10                  35             Crude
# 11                  75             Crude
# 12  Non-Hispanic White             Crude
# 15  Non-Hispanic Black             Crude
# 17            Hispanic             Crude
# 18               Other             Crude
# 20             Overall             Crude
# 23                Male             Crude
# 24              Female             Crude
# 27               25-44             Crude
# 28               45-64             Crude
# 29                  65             Crude
# 30                  35             Crude
# 31                  75             Crude
# 32  Non-Hispanic White             Crude
# 35  Non-Hispanic Black             Crude
# 38               Other             Crude
# 41             Overall             Crude
# 42                Male             Crude
# 45              Female             Crude
# 47               25-44             Crude
# 48               45-64             Crude
# 49                  65             Crude

# %%
filtered_mcd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13120 entries, 1 to 21838
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   YearStart           13120 non-null  int64
#  1   LocationAbbr        13120 non-null  object
#  2   Class               13120 non-null  object
#  3   Topic               13120 non-null  object
#  4   Data_Value          13120 non-null  float64
#  5   Break_Out_Category  13120 non-null  object
#  6   Break_Out           13120 non-null  object
#  7   Data_Value_TypeID   13120 non-null  object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 922.5+ KB

# %%
filtered_mcd_df.Break_Out_Category.value_counts()
# Out:
# Break_Out_Category
# Age        5898
# Race       3946
# Gender     2184
# Overall    1092
# Name: count, dtype: int64

# %%
age_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Age']
# Out:
# /var/folders/k7/rck94jsj7w3_47f2r29h3vn80000gn/T/ipykernel_2372/2671235090.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   age_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Age']

# %%
overall_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Overall']
# Out:
# /var/folders/k7/rck94jsj7w3_47f2r29h3vn80000gn/T/ipykernel_2372/3231300722.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   overall_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Overall']

# %%
gender_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Gender']
# Out:
# /var/folders/k7/rck94jsj7w3_47f2r29h3vn80000gn/T/ipykernel_2372/3448589801.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   gender_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Gender']

# %%
race_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Race']
# Out:
# /var/folders/k7/rck94jsj7w3_47f2r29h3vn80000gn/T/ipykernel_2372/54098473.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   race_filtered_df = filtered_mcd_df[df['Break_Out_Category'] == 'Race']

# %%
age_filtered_df.to_csv('age_filtered.csv.gz', index=False, compression='gzip') 
overall_filtered_df.to_csv('age_filtered_overall.csv.gz', index=False, compression='gzip')
gender_filtered_df.to_csv('gender_filtered.csv.gz', index=False, compression='gzip')
race_filtered_df.to_csv('race_filtered.csv.gz', index=False, compression='gzip')

# %%
gender_filtered_df = pd.read_csv('gender_filtered.csv.gz', compression='gzip')
gender_filtered_df
# Out:
#        YearStart LocationAbbr   LocationDesc                    Class  \
# 0           2000           AL        Alabama  Cardiovascular Diseases
# 1           2000           AL        Alabama  Cardiovascular Diseases
# 2           2000           AL        Alabama  Cardiovascular Diseases
# 3           2000           AL        Alabama  Cardiovascular Diseases
# 4           2000           AK         Alaska  Cardiovascular Diseases
# ...          ...          ...            ...                      ...
# 34850       2020           WY        Wyoming  Cardiovascular Diseases
# 34851       2020           US  United States  Cardiovascular Diseases
# 34852       2020           US  United States  Cardiovascular Diseases
# 34853       2020           US  United States  Cardiovascular Diseases
# 34854       2020           US  United States  Cardiovascular Diseases
#
#                               Topic  Data_Value Break_Out_Category Break_Out  \
# 0      Major Cardiovascular Disease      5149.0             Gender      Male
# 1      Major Cardiovascular Disease      5504.0             Gender      Male
# 2      Major Cardiovascular Disease      4717.0             Gender    Female
# 3      Major Cardiovascular Disease      5353.0             Gender    Female
# 4      Major Cardiovascular Disease      3220.0             Gender      Male
# ...                             ...         ...                ...       ...
# 34850                        Stroke       102.0             Gender    Female
# 34851                        Stroke       133.0             Gender      Male
# 34852                        Stroke       116.0             Gender      Male
# 34853                        Stroke       105.0             Gender    Female
# 34854                        Stroke       135.0             Gender    Female
#
#       Data_Value_TypeID  LocationId
# 0                 Crude           1
# 1               AgeStdz           1
# 2               AgeStdz           1
# 3                 Crude           1
# 4               AgeStdz           2
# ...                 ...         ...
# 34850           AgeStdz          56
# 34851             Crude          59
# 34852           AgeStdz          59
# 34853           AgeStdz          59
# 34854             Crude          59
#
# [34855 rows x 10 columns]

# %%
# Linear regression
filtered_data = gender_filtered_df[gender_filtered_df['Topic'] == 'Major Cardiovascular Disease']

# Aggregate the data by year and gender
aggregated_data = filtered_data.groupby(['YearStart', 'Break_Out'])['Data_Value'].mean().unstack()

# Plot the trends of heart attack occurrences by gender over the years
plt.figure(figsize=(12, 6))
plt.plot(aggregated_data.index, aggregated_data['Male'], label='Male', marker='o')
plt.plot(aggregated_data.index, aggregated_data['Female'], label='Female', marker='o')
plt.title('Heart Attack Occurrences by Gender Over the Years')
plt.xlabel('Year')
plt.ylabel('Average Data Value')
plt.legend()
plt.grid(True)
plt.show()

# Prepare the data for linear regression
X = aggregated_data.index.values.reshape(-1, 1)
y_male = aggregated_data['Male'].values
y_female = aggregated_data['Female'].values

# Create and train the linear regression model for males
model_male = LinearRegression()
model_male.fit(X, y_male)

# Create and train the linear regression model for females
model_female = LinearRegression()
model_female.fit(X, y_female)

# Predict future values (e.g., for the next 10 years)
future_years = np.arange(aggregated_data.index.max() + 1, aggregated_data.index.max() + 11).reshape(-1, 1)
predicted_male = model_male.predict(future_years)
predicted_female = model_female.predict(future_years)

# Plot the historical data along with the predictions
plt.figure(figsize=(12, 6))
plt.plot(aggregated_data.index, aggregated_data['Male'], label='Male (Actual)', marker='o')
plt.plot(aggregated_data.index, aggregated_data['Female'], label='Female (Actual)', marker='o')
plt.plot(future_years, predicted_male, label='Male (Predicted)', linestyle='--')
plt.plot(future_years, predicted_female, label='Female (Predicted)', linestyle='--')
plt.title('Heart Attack Occurrences by Gender (Actual and Predicted)')
plt.xlabel('Year')
plt.ylabel('Average Data Value')
plt.legend()
plt.grid(True)
plt.show()

# Predict on the historical data
predicted_male_historical = model_male.predict(X)
predicted_female_historical = model_female.predict(X)

# Calculate prediction accuracy for males
mse_male = mean_squared_error(y_male, predicted_male_historical)
r2_male = r2_score(y_male, predicted_male_historical)

# Calculate prediction accuracy for females
mse_female = mean_squared_error(y_female, predicted_female_historical)
r2_female = r2_score(y_female, predicted_female_historical)

# Display the results
accuracy_results = {
    'Male': {'MSE': mse_male, 'R^2': r2_male},
    'Female': {'MSE': mse_female, 'R^2': r2_female}
}

accuracy_results
# Out:
# {'Male': {'MSE': 54004.2814664961, 'R^2': 0.6534980220793489},
#  'Female': {'MSE': 40816.02302153214, 'R^2': 0.8491894635169304}}

# %%
filtered_data = gender_filtered_df[gender_filtered_df['Topic'] == 'Major Cardiovascular Disease']

# Aggregate the data by year and gender
aggregated_data = filtered_data.groupby(['YearStart', 'Break_Out'])['Data_Value'].mean().unstack()

# Prepare the data for regression
X = aggregated_data.index.values.reshape(-1, 1)
y_male = aggregated_data['Male'].values
y_female = aggregated_data['Female'].values

# Split the data into training and testing sets
X_train, X_test, y_male_train, y_male_test = train_test_split(X, y_male, test_size=0.2, random_state=42)
_, _, y_female_train, y_female_test = train_test_split(X, y_female, test_size=0.2, random_state=42)

# Create and train the Random Forest model for males
model_male_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_male_rf.fit(X_train, y_male_train)

# Create and train the Random Forest model for females
model_female_rf = RandomForestRegressor(n_estimators=100, random_state=42)
model_female_rf.fit(X_train, y_female_train)

# Predict on the test set
predicted_male_test_rf = model_male_rf.predict(X_test)
predicted_female_test_rf = model_female_rf.predict(X_test)

# Calculate prediction accuracy metrics for the test set
mse_male_test_rf = mean_squared_error(y_male_test, predicted_male_test_rf)
r2_male_test_rf = r2_score(y_male_test, predicted_male_test_rf)
mse_female_test_rf = mean_squared_error(y_female_test, predicted_female_test_rf)
r2_female_test_rf = r2_score(y_female_test, predicted_female_test_rf)

# Display the results
accuracy_results_test_rf = {
    'Male': {'MSE': mse_male_test_rf, 'R^2': r2_male_test_rf},
    'Female': {'MSE': mse_female_test_rf, 'R^2': r2_female_test_rf}
}

accuracy_results_test_rf
# Out:
# {'Male': {'MSE': 15236.991109540599, 'R^2': 0.941428913448488},
#  'Female': {'MSE': 15850.106107079384, 'R^2': 0.9621001386491309}}

# %%
#historical_df = pd.read_csv(csv_file_path = 'Disease_Data.csv', compression='gzip')

# %%
df.info
# Out:
# <bound method DataFrame.info of         YearStart LocationAbbr                    Class  \
# 0            2000           AL  Cardiovascular Diseases
# 1            2000           AL  Cardiovascular Diseases
# 2            2000           AL  Cardiovascular Diseases
# 3            2000           AL  Cardiovascular Diseases
# 4            2000           AL  Cardiovascular Diseases
# ...           ...          ...                      ...
# 174715       2020           US  Cardiovascular Diseases
# 174716       2020           US  Cardiovascular Diseases
# 174717       2020           US  Cardiovascular Diseases
# 174718       2020           US  Cardiovascular Diseases
# 174719       2020           US  Cardiovascular Diseases
#
#                                Topic  Data_Value Break_Out_Category  \
# 0       Major Cardiovascular Disease      5082.0            Overall
# 1       Major Cardiovascular Disease      5256.0            Overall
# 2       Major Cardiovascular Disease      5149.0             Gender
# 3       Major Cardiovascular Disease      5504.0             Gender
# 4       Major Cardiovascular Disease      4717.0             Gender
# ...                              ...         ...                ...
# 174715                        Stroke       150.0               Race
# 174716                        Stroke        84.0               Race
# 174717                        Stroke       102.0               Race
# 174718                        Stroke       116.0               Race
# 174719                        Stroke       119.0               Race
#
#                  Break_Out Data_Value_TypeID
# 0                  Overall           AgeStdz
# 1                  Overall             Crude
# 2                     Male             Crude
# 3                     Male           AgeStdz
# 4                   Female           AgeStdz
# ...                    ...               ...
# 174715  Non-Hispanic Black             Crude
# 174716            Hispanic             Crude
# 174717            Hispanic           AgeStdz
# 174718               Other           AgeStdz
# 174719               Other             Crude
#
# [143090 rows x 8 columns]>

# %%
overall_filtered_df.head()
# Out:
#     YearStart LocationAbbr                    Class  \
# 1        2000           AL  Cardiovascular Diseases
# 20       2000           AK  Cardiovascular Diseases
# 41       2000           AZ  Cardiovascular Diseases
# 60       2000           AR  Cardiovascular Diseases
# 81       2000           CA  Cardiovascular Diseases
#
#                            Topic  Data_Value Break_Out_Category Break_Out  \
# 1   Major Cardiovascular Disease      5256.0            Overall   Overall
# 20  Major Cardiovascular Disease      1871.0            Overall   Overall
# 41  Major Cardiovascular Disease      3724.0            Overall   Overall
# 60  Major Cardiovascular Disease      5546.0            Overall   Overall
# 81  Major Cardiovascular Disease      3734.0            Overall   Overall
#
#    Data_Value_TypeID
# 1              Crude
# 20             Crude
# 41             Crude
# 60             Crude
# 81             Crude

# %%
value_counts = filtered_df['YearStart'].value_counts()
print(value_counts)
# Out:
# YearStart
# 2020    4483
# 2019    4458
# 2018    4433
# 2016    4431
# 2017    4427
# 2015    4416
# 2014    4388
# 2006    4369
# 2013    4368
# 2012    4360
# 2001    4358
# 2011    4354
# 2002    4353
# 2000    4352
# 2003    4352
# 2005    4351
# 2007    4348
# 2009    4343
# 2008    4343
# 2004    4339
# 2010    4338
# Name: count, dtype: int64

# %%
# Number of columns per state per year
columns_per_state_year = 20

# Total number of states
num_states = 50

# Total number of years
num_years = 22

# Separating the dataset by blocks of columns for each state and year
blocks = []
for state_index in range(num_states):
    for year_index in range(num_years):
        start_col = (state_index * num_years * columns_per_state_year) + (year_index * columns_per_state_year)
        end_col = start_col + columns_per_state_year
        block = df.iloc[:, start_col:end_col]
        blocks.append(block)

# %%
for column in age_filtered_df.select_dtypes(include='number').columns:
    plt.figure()
    plt.hist(age_filtered_df[column], bins=30)
    plt.xlabel(column)
    plt.ylabel('Frequency')
    plt.title(f'Histogram of {column}')
    plt.show()

# %%
from sklearn.cluster import KMeans

# %%
# Example data preparation
data = overall_filtered_df[['Data_Value', 'Break_Out']]

# Ensure the data is numeric and drop rows with non-numeric values
data = data.apply(pd.to_numeric, errors='coerce')
data = data.dropna()

# Verify the data
print(data.head())

# Define the number of clusters
k = 3

# Apply K-means clustering
kmeans = KMeans(n_clusters=k, random_state=0)
kmeans.fit(data)

# Get cluster labels
labels = kmeans.labels_

# Add the cluster labels to the original DataFrame
overall_filtered_df = overall_filtered_df.loc[data.index]  # Ensure the DataFrame matches the cleaned data
overall_filtered_df['Cluster'] = labels

# Plotting the clusters
plt.figure(figsize=(10, 6))

# Scatter plot of the data points with cluster coloring
plt.scatter(data['feature1'], data['feature2'], c=labels, cmap='viridis', marker='o', edgecolor='k')

# Plotting the cluster centers
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', s=300, alpha=0.6, marker='x', label='Centroids')

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('K-means Clustering')
plt.legend()
plt.show()
# Out:
# Empty DataFrame
# Columns: [Data_Value, Break_Out]
# Index: []
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[525], line 16
#      14 # Apply K-means clustering
#      15 kmeans = KMeans(n_clusters=k, random_state=0)
# ---> 16 kmeans.fit(data)
#      18 # Get cluster labels
#      19 labels = kmeans.labels_
#
# File /opt/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File /opt/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/cluster/_kmeans.py:1461, in KMeans.fit(self, X, y, sample_weight)
#    1433 @_fit_context(prefer_skip_nested_validation=True)
#    1434 def fit(self, X, y=None, sample_weight=None):
#    1435     """Compute k-means clustering.
#    1436
#    1437     Parameters
#    (...)
#    1459         Fitted estimator.
#    1460     """
# -> 1461     X = self._validate_data(
#    1462         X,
#    1463         accept_sparse="csr",
#    1464         dtype=[np.float64, np.float32],
#    1465         order="C",
#    1466         copy=self.copy_x,
#    1467         accept_large_sparse=False,
#    1468     )
#    1470     self._check_params_vs_input(X)
#    1472     random_state = check_random_state(self.random_state)
#
# File /opt/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File /opt/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/validation.py:1082, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1080     n_samples = _num_samples(array)
#    1081     if n_samples < ensure_min_samples:
# -> 1082         raise ValueError(
#    1083             "Found array with %d sample(s) (shape=%s) while a"
#    1084             " minimum of %d is required%s."
#    1085             % (n_samples, array.shape, ensure_min_samples, context)
#    1086         )
#    1088 if ensure_min_features > 0 and array.ndim == 2:
#    1089     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required by KMeans.
