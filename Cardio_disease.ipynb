# %%
import pandas as pd
import numpy as np
import re

# %%
file_name = "Disease_Data.csv"

# %%
df = pd.read_csv(file_name, sep = ';')

pd.set_option('display.max_columns', None)
df.head(5)
# Out:
# /var/folders/gb/k5_c79td0fl5rm4xf6x4ytgr0000gp/T/ipykernel_59459/3608972064.py:1: DtypeWarning: Columns (5,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_name, sep = ';')
#                                       RowId  YearStart LocationAbbr  \
# 0  NVSS~2000~1~NV001~OVR01~Age-Standardized       2000           AL
# 1             NVSS~2000~1~NV001~OVR01~Crude       2000           AL
# 2             NVSS~2000~1~NV001~GEN01~Crude       2000           AL
# 3  NVSS~2000~1~NV001~GEN01~Age-Standardized       2000           AL
# 4  NVSS~2000~1~NV001~GEN02~Age-Standardized       2000           AL
#
#   LocationDesc DataSource PriorityArea1  PriorityArea2 PriorityArea3  \
# 0      Alabama       NVSS           NaN            NaN           NaN
# 1      Alabama       NVSS           NaN            NaN           NaN
# 2      Alabama       NVSS           NaN            NaN           NaN
# 3      Alabama       NVSS           NaN            NaN           NaN
# 4      Alabama       NVSS           NaN            NaN           NaN
#
#    PriorityArea4                    Class                         Topic  \
# 0            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 1            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 2            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 3            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
# 4            NaN  Cardiovascular Diseases  Major Cardiovascular Disease
#
#                                             Question   Data_Value_Type  \
# 0  Major cardiovascular disease mortality rate am...  Age-Standardized
# 1  Major cardiovascular disease mortality rate am...             Crude
# 2  Major cardiovascular disease mortality rate am...             Crude
# 3  Major cardiovascular disease mortality rate am...  Age-Standardized
# 4  Major cardiovascular disease mortality rate am...  Age-Standardized
#
#     Data_Value_Unit Data_Value Data_Value_Alt Data_Value_Footnote_Symbol  \
# 0  Rate per 100,000      508,2          508,2                        NaN
# 1  Rate per 100,000      525,6          525,6                        NaN
# 2  Rate per 100,000      514,9          514,9                        NaN
# 3  Rate per 100,000      550,4          550,4                        NaN
# 4  Rate per 100,000      471,7          471,7                        NaN
#
#   Data_Value_Footnote Low_Confidence_Limit High_Confidence_Limit  \
# 0                 NaN                508,2                 508,2
# 1                 NaN                525,6                 525,6
# 2                 NaN                514,9                 514,9
# 3                 NaN                550,4                 550,4
# 4                 NaN                471,7                 471,7
#
#   Break_Out_Category Break_Out ClassId TopicId QuestionId Data_Value_TypeID  \
# 0            Overall   Overall      C1      T1      NV001           AgeStdz
# 1            Overall   Overall      C1      T1      NV001             Crude
# 2             Gender      Male      C1      T1      NV001             Crude
# 3             Gender      Male      C1      T1      NV001           AgeStdz
# 4             Gender    Female      C1      T1      NV001           AgeStdz
#
#   BreakOutCategoryId BreakOutId  LocationId                       Geolocation
# 0              BOC01      OVR01           1  POINT (-86.63186076 32.84057112)
# 1              BOC01      OVR01           1  POINT (-86.63186076 32.84057112)
# 2              BOC02      GEN01           1  POINT (-86.63186076 32.84057112)
# 3              BOC02      GEN01           1  POINT (-86.63186076 32.84057112)
# 4              BOC02      GEN02           1  POINT (-86.63186076 32.84057112)

# %%
df.Data_Value_Unit.unique()
# Out:
# array(['Rate per 100,000'], dtype=object)

# %%
df.Break_Out.unique()
# Out:
# array(['Overall', 'Male', 'Female', '18-24', '25-44', '45-64', '65', '35',
#        '75', 'Non-Hispanic White', 'Non-Hispanic Black', 'Hispanic',
#        'Other'], dtype=object)

# %%
df.BreakOutId.unique()
# Out:
# array(['OVR01', 'GEN01', 'GEN02', 'AGE01', 'AGE04', 'AGE05', 'AGE06',
#        'AGE07', 'AGE08', 'RAC01', 'RAC02', 'RAC04', 'RAC07'], dtype=object)

# %%
df.Break_Out_Category.value_counts()
# Out:
# Break_Out_Category
# Race       69888
# Age        52416
# Gender     34944
# Overall    17472
# Name: count, dtype: int64

# %%
df.YearStart.value_counts()
# Out:
# YearStart
# 2000    8320
# 2011    8320
# 2019    8320
# 2018    8320
# 2017    8320
# 2016    8320
# 2015    8320
# 2014    8320
# 2013    8320
# 2012    8320
# 2010    8320
# 2001    8320
# 2009    8320
# 2008    8320
# 2007    8320
# 2006    8320
# 2005    8320
# 2004    8320
# 2003    8320
# 2002    8320
# 2020    8320
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# RowId                              0
# YearStart                          0
# LocationAbbr                       0
# LocationDesc                       0
# DataSource                         0
# PriorityArea1                 131040
# PriorityArea2                 174720
# PriorityArea3                 131040
# PriorityArea4                 174720
# Class                              0
# Topic                              0
# Question                           0
# Data_Value_Type                    0
# Data_Value_Unit                    0
# Data_Value                     31630
# Data_Value_Alt                     0
# Data_Value_Footnote_Symbol    143090
# Data_Value_Footnote           143090
# Low_Confidence_Limit           31630
# High_Confidence_Limit          31630
# Break_Out_Category                 0
# Break_Out                          0
# ClassId                            0
# TopicId                            0
# QuestionId                         0
# Data_Value_TypeID                  0
# BreakOutCategoryId                 0
# BreakOutId                         0
# LocationId                         0
# Geolocation                     3360
# dtype: int64

# %%
df.dtypes
# Out:
# RowId                          object
# YearStart                       int64
# LocationAbbr                   object
# LocationDesc                   object
# DataSource                     object
# PriorityArea1                  object
# PriorityArea2                 float64
# PriorityArea3                  object
# PriorityArea4                 float64
# Class                          object
# Topic                          object
# Question                       object
# Data_Value_Type                object
# Data_Value_Unit                object
# Data_Value                     object
# Data_Value_Alt                 object
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Low_Confidence_Limit           object
# High_Confidence_Limit          object
# Break_Out_Category             object
# Break_Out                      object
# ClassId                        object
# TopicId                        object
# QuestionId                     object
# Data_Value_TypeID              object
# BreakOutCategoryId             object
# BreakOutId                     object
# LocationId                      int64
# Geolocation                    object
# dtype: object

# %%
df = df.drop(df[df['Break_Out_Category'] == 'Race'].index) 
df = df.drop(df[df['Break_Out_Category'] == 'Gender'].index) 
df = df.drop(df[df['Data_Value_Type'] == 'Age-Standardized'].index)

# %%
df = df.drop(df[df['Data_Value'] == ''].index) 
df = df.drop(df[df['Data_Value_Alt'] == ''].index) 
df.dropna(subset=['Data_Value'], inplace=True)

# %%
df['Data_Value'] = df['Data_Value'].str.replace(',','')
df['Data_Value_Alt'] = df['Data_Value_Alt'].str.replace(',','')

df['Data_Value'] = df['Data_Value'].astype(float)
df['Data_Value_Alt'] = df['Data_Value_Alt'].astype(float)

# %%
df.shape
# Out:
# (49459, 30)

# %%
columns = df.columns.to_list()
columns
# Out:
# ['RowId',
#  'YearStart',
#  'LocationAbbr',
#  'LocationDesc',
#  'DataSource',
#  'PriorityArea1',
#  'PriorityArea2',
#  'PriorityArea3',
#  'PriorityArea4',
#  'Class',
#  'Topic',
#  'Question',
#  'Data_Value_Type',
#  'Data_Value_Unit',
#  'Data_Value',
#  'Data_Value_Alt',
#  'Data_Value_Footnote_Symbol',
#  'Data_Value_Footnote',
#  'Low_Confidence_Limit',
#  'High_Confidence_Limit',
#  'Break_Out_Category',
#  'Break_Out',
#  'ClassId',
#  'TopicId',
#  'QuestionId',
#  'Data_Value_TypeID',
#  'BreakOutCategoryId',
#  'BreakOutId',
#  'LocationId',
#  'Geolocation']

# %%
df.isna().sum()
# Out:
# claim_identifier                                   0
# patient_identifier                                 0
# payer_member_identifier                            0
# claim_status_code                                  0
# claim_addressed_date                               0
#                                                ...
# procedure_code_modifier_and_description_24    661645
# procedure_date_25                             661645
# procedure_code_25                             661645
# procedure_code_type_25                             0
# procedure_code_modifier_and_description_25    661645
# Length: 164, dtype: int64

# %%
df.drop_duplicates()
# Out:
#                                  RowId  YearStart LocationAbbr   LocationDesc  \
# 1        NVSS~2000~1~NV001~OVR01~Crude       2000           AL        Alabama
# 6        NVSS~2000~1~NV001~AGE01~Crude       2000           AL        Alabama
# 7        NVSS~2000~1~NV001~AGE04~Crude       2000           AL        Alabama
# 8        NVSS~2000~1~NV001~AGE05~Crude       2000           AL        Alabama
# 9        NVSS~2000~1~NV001~AGE06~Crude       2000           AL        Alabama
# ...                                ...        ...          ...            ...
# 174707  NVSS~2020~59~NV008~AGE04~Crude       2020           US  United States
# 174708  NVSS~2020~59~NV008~AGE05~Crude       2020           US  United States
# 174709  NVSS~2020~59~NV008~AGE06~Crude       2020           US  United States
# 174710  NVSS~2020~59~NV008~AGE07~Crude       2020           US  United States
# 174711  NVSS~2020~59~NV008~AGE08~Crude       2020           US  United States
#
#        DataSource PriorityArea1  PriorityArea2 PriorityArea3  PriorityArea4  \
# 1            NVSS           NaN            NaN           NaN            NaN
# 6            NVSS           NaN            NaN           NaN            NaN
# 7            NVSS           NaN            NaN           NaN            NaN
# 8            NVSS           NaN            NaN           NaN            NaN
# 9            NVSS           NaN            NaN           NaN            NaN
# ...           ...           ...            ...           ...            ...
# 174707       NVSS           NaN            NaN           NaN            NaN
# 174708       NVSS           NaN            NaN           NaN            NaN
# 174709       NVSS           NaN            NaN           NaN            NaN
# 174710       NVSS           NaN            NaN           NaN            NaN
# 174711       NVSS           NaN            NaN           NaN            NaN
#
#                           Class                         Topic  \
# 1       Cardiovascular Diseases  Major Cardiovascular Disease
# 6       Cardiovascular Diseases  Major Cardiovascular Disease
# 7       Cardiovascular Diseases  Major Cardiovascular Disease
# 8       Cardiovascular Diseases  Major Cardiovascular Disease
# 9       Cardiovascular Diseases  Major Cardiovascular Disease
# ...                         ...                           ...
# 174707  Cardiovascular Diseases                        Stroke
# 174708  Cardiovascular Diseases                        Stroke
# 174709  Cardiovascular Diseases                        Stroke
# 174710  Cardiovascular Diseases                        Stroke
# 174711  Cardiovascular Diseases                        Stroke
#
#                                                  Question Data_Value_Type  \
# 1       Major cardiovascular disease mortality rate am...           Crude
# 6       Major cardiovascular disease mortality rate am...           Crude
# 7       Major cardiovascular disease mortality rate am...           Crude
# 8       Major cardiovascular disease mortality rate am...           Crude
# 9       Major cardiovascular disease mortality rate am...           Crude
# ...                                                   ...             ...
# 174707  Hemorrhagic stroke mortality rate among US adu...           Crude
# 174708  Hemorrhagic stroke mortality rate among US adu...           Crude
# 174709  Hemorrhagic stroke mortality rate among US adu...           Crude
# 174710  Hemorrhagic stroke mortality rate among US adu...           Crude
# 174711  Hemorrhagic stroke mortality rate among US adu...           Crude
#
#          Data_Value_Unit  Data_Value  Data_Value_Alt  \
# 1       Rate per 100,000   5256.0000       5256.0000
# 6       Rate per 100,000     54.0000         54.0000
# 7       Rate per 100,000    382.0000        382.0000
# 8       Rate per 100,000   2734.0000       2734.0000
# 9       Rate per 100,000      2.4428          2.4428
# ...                  ...         ...             ...
# 174707  Rate per 100,000     19.0000         19.0000
# 174708  Rate per 100,000     99.0000         99.0000
# 174709  Rate per 100,000    439.0000        439.0000
# 174710  Rate per 100,000    188.0000        188.0000
# 174711  Rate per 100,000    752.0000        752.0000
#
#        Data_Value_Footnote_Symbol Data_Value_Footnote Low_Confidence_Limit  \
# 1                             NaN                 NaN                525,6
# 6                             NaN                 NaN                  5,3
# 7                             NaN                 NaN                 38,1
# 8                             NaN                 NaN                273,4
# 9                             NaN                 NaN              2.442,8
# ...                           ...                 ...                  ...
# 174707                        NaN                 NaN                  1,9
# 174708                        NaN                 NaN                  9,9
# 174709                        NaN                 NaN                 43,9
# 174710                        NaN                 NaN                 18,8
# 174711                        NaN                 NaN                 75,2
#
#        High_Confidence_Limit Break_Out_Category Break_Out ClassId TopicId  \
# 1                      525,6            Overall   Overall      C1      T1
# 6                          8                Age     18-24      C1      T1
# 7                       38,3                Age     25-44      C1      T1
# 8                      273,4                Age     45-64      C1      T1
# 9                    2.442,8                Age        65      C1      T1
# ...                      ...                ...       ...     ...     ...
# 174707                   1,9                Age     25-44      C1      T6
# 174708                   9,9                Age     45-64      C1      T6
# 174709                  43,9                Age        65      C1      T6
# 174710                  18,8                Age        35      C1      T6
# 174711                  75,2                Age        75      C1      T6
#
#        QuestionId Data_Value_TypeID BreakOutCategoryId BreakOutId  LocationId  \
# 1           NV001             Crude              BOC01      OVR01           1
# 6           NV001             Crude              BOC03      AGE01           1
# 7           NV001             Crude              BOC03      AGE04           1
# 8           NV001             Crude              BOC03      AGE05           1
# 9           NV001             Crude              BOC03      AGE06           1
# ...           ...               ...                ...        ...         ...
# 174707      NV008             Crude              BOC03      AGE04          59
# 174708      NV008             Crude              BOC03      AGE05          59
# 174709      NV008             Crude              BOC03      AGE06          59
# 174710      NV008             Crude              BOC03      AGE07          59
# 174711      NV008             Crude              BOC03      AGE08          59
#
#                              Geolocation
# 1       POINT (-86.63186076 32.84057112)
# 6       POINT (-86.63186076 32.84057112)
# 7       POINT (-86.63186076 32.84057112)
# 8       POINT (-86.63186076 32.84057112)
# 9       POINT (-86.63186076 32.84057112)
# ...                                  ...
# 174707                               NaN
# 174708                               NaN
# 174709                               NaN
# 174710                               NaN
# 174711                               NaN
#
# [49459 rows x 30 columns]
